# %% [markdown]
# <a href="https://colab.research.google.com/github/saksham1211/Marketingai_Internship/blob/master/Unsupervised_TopicModeling_V1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('/content/Book2.csv')
df.head()
# Out:
#    SLNo.  ...                   CITY
# 0      0  ...       Boston, MA,02210
# 1      1  ...     New York, NY,10022
# 2      2  ...     New York, NY,10173
# 3      3  ...    San Diego, CA,92130
# 4      4  ...  Los Angeles, CA,90025
#
# [5 rows x 4 columns]

# %%
document = list(df['DESCRIPTION'])
document
# Out:
# ['Use this form to transfer all or a portion of your account from another financial institution to your Merrill Lynch, Pierce, Fenner & Smith Incorporated (“Merrill Lynch”) account',
#  'For best results, please complete the information requested below in parts 1 to 4 using ALL CAPITAL letters and black ink. If you need more room for information or signatures, use a copy of the relevant page or a blank sheet. Use one form for each account that you’re transferring',
#  'Many firms transfer assets using an automated transfer process, which typically takes 5 to 6 business days. Other firms either don’t use the automated process or must process some assets manually, which takes more time. The following estimated time frames for manual transfers are from the date of receipt of instructions by the delivering firm and may vary greatly',
#  'Remember to update any automatic deposits or withdrawals you’ve set up on the account you’re transferring to Merrill Lynch',
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
import numpy as np
import pandas as pd

# %%
vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(document)

# %%
true_k = 6
model = KMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)
model.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=100,
#        n_clusters=6, n_init=1, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
order_centroids = model.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names()
order_centroids
# Out:
# array([[  59, 1478, 1189, ...,  896,  899,  745],
#        [1113, 1224, 1369, ...,  952,  953,  745],
#        [ 164,  350,  637, ...,  921,  922,    0],
#        [ 892,  848,   59, ...,  945,  947,    0],
#        [1393,  738,  596, ...,  886,  884,    0],
#        [  59,  666, 1240, ...,  923,  924,    0]])

# %%
terms
# Out:
# ['00',
#  '000',
#  '10',
#  '100',
#  '11870',
#  '12',
#  '13',
#  '13th',
#  '14',
#  '150',
#  '15g',
#  '15h',
#  '19',
#  '1977',
#  '1995',
#  '20',
#  '20000',
#  '2008',
#  '2016',
#  '2018',
#  '23',
#  '25',
#  '250',
#  '26',
#  '29',
#  '30',
#  '31000',
#  '33',
#  '3500',
#  '3a',
#  '3b',
#  '401',
#  '403',
#  '431',
#  '50',
#  '5000',
#  '529',
#  '59½',
#  '60',
#  '65',
#  '800',
#  '80d',
#  '87',
#  '870',
#  '90',
#  '93',
#  '9668',
#  '99',
#  'ability',
#  'able',
#  'abroad',
#  'acat',
#  'accept',
#  'accepted',
#  'accepting',
#  'accepts',
#  'access',
#  'accident',
#  'accidents',
#  'account',
#  'accounting',
#  'accounts',
#  'accrued',
#  'accuracy',
#  'accurate',
#  'achieve',
#  'acknowledge',
#  'acquire',
#  'acquiring',
#  'acquisition',
#  'act',
#  'action',
#  'actions',
#  'active',
#  'acts',
#  'add',
#  'added',
#  'addition',
#  'additional',
#  'additionally',
#  'address',
#  'adds',
#  'adequate',
#  'administration',
# ...

# %%
for i in range(true_k):
 print("Cluster %d:" % i)
 for ind in order_centroids[i, :50]:
  print("%s" % terms[ind])
 print("\n")
# Out:
# Cluster 0:
# account
# withholding
# required
# distribution
# tax
# state
# advisor
# investment
# assets
# election
# transferring
# beneficiary
# income
# time
# period
# transferred
# retirement
# schwab
# instruction
# portions
# event
# statement
# needs
# patient
# includes
# federal
# td
# ameritrade
# results
# irs
# minimum
# insured
# penalties
# options
# rule
# payment
# emis
# party
# spouse
# information
# nature
# readily
# best
# copy
# understand
# orders
# based
# applicable
# goals
# maturity
#
#
# Cluster 1:
# rate
# rs
# term
# applicable
# deposit
# 50
# 00
# senior
# paid
# citizens
# tenors
# lacs
# tax
# deposits
# premature
# penalty
# 15g
# tds
# quarterly
# shall
# withdrawal
# submitted
# sbi
# 60
# rules
# payout
# refers
# age
# liability
# regular
# 000
# income
# crore
# years
# monthly
# prevalent
# form
# payment
# contracted
# deduction
# depositor
# exemption
# retail
# period
# records
# compounding
# cargo
# vessel
# insurance
# 20000
#
#
# ...

# %%
def category_name(predicted_category):
  t=predicted_category[0]
  if t == [0]:
    return('AMERITRADE')
  elif t==[1]:
    return('SBI')
  elif t==[2]:
    return('HDFC')
  elif t==[3]:
    return('MERRILL LYNCH')
  elif t==[4]:
    return('ICICI LOMBARD')
  elif t==[5]:
    return('CHARLES SCHWAB')

# %%
print("Prediction")
#MERRILL LYNCH
X = vectorizer.transform(["Use this form to transfer all or a portion of your account from another financial institution to your Merrill Lynch, Pierce, Fenner & Smith Incorporated (“Merrill Lynch”) account"])
predicted = category_name(model.predict(X))
print(predicted)
# Out:
# Prediction
# MERRILL LYNCH

# %%
print("Prediction")
#AMERITRADE
X = vectorizer.transform(["When transferring from a joint account at a contra firm to an individual account at TD Ameritrade, the party losing ownership of the assets must sign section 4. If the party losing ownership does not have an account at TD Ameritrade, please attach a notarized letter of authorization signed by the party losing ownership of the assets. If the discrepancy is a result of a name change for an account owner, please provide a copy of the legal document such as a marriage certificate, divorce decree, etc. Further documentation may be required, depending on the situation"])
predicted = category_name(model.predict(X))
print(predicted)
# Out:
# Prediction
# AMERITRADE

# %%
print("Prediction")
#SCHWAB
X = vectorizer.transform(["A Schwab Qualified Plan is a Schwab Profit Sharing Qualified Retirement Plan or Keogh, a Schwab Individual 401(k), or a Schwab 403(b)(7) Account. State Income Tax Withholding: State tax withholding may be"])
predicted = category_name(model.predict(X))
print(predicted)
# Out:
# Prediction
# CHARLES SCHWAB

# %%
print("Prediction")
#ICICI_LOMBARD
X = vectorizer.transform(["Well, we don’t wish to blow our own trumpet, but the Indian Insurance Award of ‘Claim Leader – General Insurance’ only validates why we remain your smartest choice."])
predicted = category_name(model.predict(X))
print(predicted)
# Out:
# Prediction
# ICICI LOMBARD

# %%
print("Prediction")
#HDFC
X = vectorizer.transform(["HDFC Group has donated INR 150 Crores to the PM Cares Fund to support the government in fighting the COVID situation"])
predicted = category_name(model.predict(X))
print(predicted)
# Out:
# Prediction
# HDFC

# %%
print("Prediction")
#SBI 
X = vectorizer.transform(["Payment of Monthly interest will be at discounted rate. Interest will be paid at the contracted rate irrespective of change in the rates thereafter."])
predicted = category_name(model.predict(X))
print(predicted)
# Out:
# Prediction
# SBI
